# %% [markdown]
# <a href="https://colab.research.google.com/github/shorub/Projects/blob/main/Unsupervised_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Country-data.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
features = ['child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp']
x = df.loc[:, features].values
x = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principal_df = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(principal_df)
labels = kmeans.labels_

# %%
df['PC1'] = principal_df['PC1']
df['PC2'] = principal_df['PC2']
df['Group'] = labels
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp       PC1       PC2  Group
# 0         9.44        56.2       5.82    553 -2.913025  0.095621      2
# 1         4.49        76.3       1.65   4090  0.429911 -0.588156      0
# 2        16.10        76.5       2.89   4460 -0.285225 -0.455174      0
# 3        22.40        60.1       6.16   3530 -2.932423  1.695555      2
# 4         1.44        76.8       2.13  12200  1.033576  0.136659      0
# ..         ...         ...        ...    ...       ...       ...    ...
# 162       2.62        63.0       3.50   2970 -0.820631  0.639570      0
# 163      45.90        75.4       2.47  13500 -0.551036 -1.233886      0
# 164      12.10        73.1       1.95   1310  0.498524  1.390744      0
# 165      23.60        67.5       4.67   1310 -1.887451 -0.109453      2
# 166      14.00        52.0       5.40   1460 -2.864064  0.485998      2
#
# [167 rows x 13 columns]

# %%
df['Group'].unique()
# Out:
# array([2, 0, 1], dtype=int32)

# %% [markdown]
# **Wholesale Customers data**

# %%
df = pd.read_csv('Wholesale customers data.csv')
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %%
features = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']
x = df.loc[:, features].values
x = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components = 2)
principalComponents = pca.fit_transform(x)
principal_df = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(principal_df)
labels = kmeans.labels_

# %%
df['PC1'] = principal_df['PC1']
df['PC2'] = principal_df['PC2']
df['Group'] = labels
df[df['Group'] == 2]
# Out:
#      Channel  Region   Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 181        1       3  112151  29627    18148   16745              4948
# 183        1       3   36847  43950    20170   36534               239
# 325        1       2   32717  16784    13626   60869              1272
#
#      Delicassen       PC1        PC2  Group
# 181        8550  3.726959   7.167539      2
# 183       47943  7.797940  13.949084      2
# 325        5609  2.014356   9.005487      2
